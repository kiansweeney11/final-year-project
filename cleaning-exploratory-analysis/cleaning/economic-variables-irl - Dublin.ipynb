# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

# %% [markdown]
# ## Let's investigate the impact economic factors may have on prices in Dublin

# %%
unemploy_cso = pd.read_csv('economy-factors/unemploy-cso.csv')

# %%
unemploy_cso
# Out:
#                           Statistic    Month       Age Group         Sex  \
# 0      Persons on the Live Register  2009M10  Under 20 years  Both sexes
# 1      Persons on the Live Register  2009M10  Under 20 years  Both sexes
# 2      Persons on the Live Register  2009M10  Under 20 years  Both sexes
# 3      Persons on the Live Register  2009M10  Under 20 years        Male
# 4      Persons on the Live Register  2009M10  Under 20 years        Male
# ...                             ...      ...             ...         ...
# 13225  Persons on the Live Register  2021M12        All ages        Male
# 13226  Persons on the Live Register  2021M12        All ages        Male
# 13227  Persons on the Live Register  2021M12        All ages      Female
# 13228  Persons on the Live Register  2021M12        All ages      Female
# 13229  Persons on the Live Register  2021M12        All ages      Female
#
#                  Duration  VALUE
# 0           All durations  15370
# ...

# %%
unemploy_all = unemploy_cso.loc[(unemploy_cso['Age Group'] == 'All ages') & (unemploy_cso['Sex'] == 'Both sexes') &
                (unemploy_cso['Duration'] == 'All durations')]

# %%
unemploy_all
# Out:
#                           Statistic    Month Age Group         Sex  \
# 81     Persons on the Live Register  2009M10  All ages  Both sexes
# 171    Persons on the Live Register  2009M11  All ages  Both sexes
# 261    Persons on the Live Register  2009M12  All ages  Both sexes
# 351    Persons on the Live Register  2010M01  All ages  Both sexes
# 441    Persons on the Live Register  2010M02  All ages  Both sexes
# ...                             ...      ...       ...         ...
# 12861  Persons on the Live Register  2021M08  All ages  Both sexes
# 12951  Persons on the Live Register  2021M09  All ages  Both sexes
# 13041  Persons on the Live Register  2021M10  All ages  Both sexes
# 13131  Persons on the Live Register  2021M11  All ages  Both sexes
# 13221  Persons on the Live Register  2021M12  All ages  Both sexes
#
#             Duration   VALUE
# 81     All durations  412407
# 171    All durations  413505
# 261    All durations  423595
# 351    All durations  436936
# ...

# %%
date = np.array(unemploy_all['Month'])
month = []
year = []
for i in range(len(date)):
    y = date[i][:4]
    m = date[i][-2:]
    year.append(y)
    month.append(m)

# %%
len(year)
# Out:
# 147

# %%
#month

# %%
unemploy_all['Year'] = year
unemploy_all['Month'] = month
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/422704436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemploy_all['Year'] = year
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/422704436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemploy_all['Month'] = month

# %%
unemploy_all
# Out:
#                           Statistic Month Age Group         Sex  \
# 81     Persons on the Live Register    10  All ages  Both sexes
# 171    Persons on the Live Register    11  All ages  Both sexes
# 261    Persons on the Live Register    12  All ages  Both sexes
# 351    Persons on the Live Register    01  All ages  Both sexes
# 441    Persons on the Live Register    02  All ages  Both sexes
# ...                             ...   ...       ...         ...
# 12861  Persons on the Live Register    08  All ages  Both sexes
# 12951  Persons on the Live Register    09  All ages  Both sexes
# 13041  Persons on the Live Register    10  All ages  Both sexes
# 13131  Persons on the Live Register    11  All ages  Both sexes
# 13221  Persons on the Live Register    12  All ages  Both sexes
#
#             Duration   VALUE  Year
# 81     All durations  412407  2009
# 171    All durations  413505  2009
# 261    All durations  423595  2009
# 351    All durations  436936  2010
# ...

# %%
date = np.array(unemploy_all['Month'])
month = []
for i in range(len(date)):
    if date[i][-2] == "0":
        m = date[i][-1]
        month.append(m)
    else:
        m = date[i][-2:]
        month.append(m)

# %%
len(month)
# Out:
# 147

# %%
unemploy_all['Month'] = month
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/297727059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemploy_all['Month'] = month

# %%
unemploy_all
# Out:
#                           Statistic Month Age Group         Sex  \
# 81     Persons on the Live Register    10  All ages  Both sexes
# 171    Persons on the Live Register    11  All ages  Both sexes
# 261    Persons on the Live Register    12  All ages  Both sexes
# 351    Persons on the Live Register     1  All ages  Both sexes
# 441    Persons on the Live Register     2  All ages  Both sexes
# ...                             ...   ...       ...         ...
# 12861  Persons on the Live Register     8  All ages  Both sexes
# 12951  Persons on the Live Register     9  All ages  Both sexes
# 13041  Persons on the Live Register    10  All ages  Both sexes
# 13131  Persons on the Live Register    11  All ages  Both sexes
# 13221  Persons on the Live Register    12  All ages  Both sexes
#
#             Duration   VALUE  Year
# 81     All durations  412407  2009
# 171    All durations  413505  2009
# 261    All durations  423595  2009
# 351    All durations  436936  2010
# ...

# %%
unemploy_all.drop(columns=['Statistic', 'Sex', 'Age Group', 'Duration'], inplace=True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
unemploy_all.rename(columns={'VALUE': 'Unemployment Number'}, inplace=True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
unemploy_all
# Out:
#       Month  Unemployment Number  Year
# 81       10               412407  2009
# 171      11               413505  2009
# 261      12               423595  2009
# 351       1               436936  2010
# 441       2               436956  2010
# ...     ...                  ...   ...
# 12861     8               179761  2021
# 12951     9               162898  2021
# 13041    10               165671  2021
# 13131    11               164626  2021
# 13221    12               163856  2021
#
# [147 rows x 3 columns]

# %%
unemploy_all.dtypes
# Out:
# Month                  object
# Unemployment Number     int64
# Year                   object
# dtype: object

# %%
unemploy_all["Month"] = unemploy_all["Month"].astype('int64')
unemploy_all["Year"] = unemploy_all["Year"].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/848529816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemploy_all["Month"] = unemploy_all["Month"].astype('int64')
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/848529816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemploy_all["Year"] = unemploy_all["Year"].astype('int64')

# %%
unemploy_all.dtypes
# Out:
# Month                  int64
# Unemployment Number    int64
# Year                   int64
# dtype: object

# %%
res = pd.read_csv('initial-ml-test-dub-1.csv', index_col = 'Unnamed: 0')

# %%
res.head()
# Out:
#                                                   Address  County  Price (€)  \
# 207901                        55 College Square, Terenure  Dublin  447200.00
# 207905   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 207916  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 207925                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 207929          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#         VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 207901              0             0                          1  2014      1
# 207905              1             1                          0  2014      1
# 207916              0             0                          1  2014      1
# 207925              1             1                          1  2014      1
# 207929              1             1                          2  2014      1
#
# ...

# %%
merged_inner = pd.merge(left = res, right = unemploy_all, left_on=['Year', 'Month'], right_on=['Year', 'Month'])

# %%
#merged_inner.drop(columns=['Unnamed: 0'], inplace=True)

# %%
merged_inner.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceSchool  DistancePark DistanceLuas  \
# ...

# %%
#merged_inner.to_csv('unemploydata.csv')

# %%
inf13_21 = pd.read_csv('economy-factors/inflation-irl-13-21.csv')

# %%
inf13_21
# Out:
#          Month Monthly Change Annual Change
# 0    01-Jan-13         -0.50%         1.20%
# 1    01-Feb-13          0.80%         1.10%
# 2    01-Mar-13          0.40%         0.50%
# 3    01-Apr-13              0         0.50%
# 4    01-May-13         -0.10%         0.40%
# ..         ...            ...           ...
# 102  01-Jul-21          0.40%         2.20%
# 103  01-Aug-21          0.60%         2.80%
# 104  01-Sep-21          0.50%         3.70%
# 105  01-Oct-21          0.70%         5.10%
# 106  01-Nov-21          0.60%         5.30%
#
# [107 rows x 3 columns]

# %%
ann = np.array(inf13_21['Annual Change'])
mon = np.array(inf13_21['Monthly Change'])
annual = []
for i in range(len(ann)):
    if ann[i][-1] == "%":
        annual.append(ann[i][:-1])
    else:
        annual.append(ann[i])

# %%
len(annual)
# Out:
# 107

# %%
month = []
for i in range(len(mon)):
    if mon[i][-1] == "%":
        month.append(mon[i][:-1])
    else:
        month.append(mon[i])

# %%
len(month)
# Out:
# 107

# %%
inf13_21['Annual Change'] = annual
inf13_21['Monthly Change'] = month

# %%
inf13_21
# Out:
#          Month Monthly Change Annual Change
# 0    01-Jan-13          -0.50          1.20
# 1    01-Feb-13           0.80          1.10
# 2    01-Mar-13           0.40          0.50
# 3    01-Apr-13              0          0.50
# 4    01-May-13          -0.10          0.40
# ..         ...            ...           ...
# 102  01-Jul-21           0.40          2.20
# 103  01-Aug-21           0.60          2.80
# 104  01-Sep-21           0.50          3.70
# 105  01-Oct-21           0.70          5.10
# 106  01-Nov-21           0.60          5.30
#
# [107 rows x 3 columns]

# %%
date = np.array(inf13_21['Month'])
month_val = []
year = []
for i in range(len(date)):
    split = date[i].split("-")
    month = split[1]
    year1 = "20" + split[-1]
    month_val.append(month)
    year.append(year1)

# %%
#month_val

# %%
#year

# %%
inf13_21['Year'] = year
inf13_21['Month'] = month_val

# %%
inf13_21.head(12)
# Out:
#    Month Monthly Change Annual Change  Year
# 0    Jan          -0.50          1.20  2013
# 1    Feb           0.80          1.10  2013
# 2    Mar           0.40          0.50  2013
# 3    Apr              0          0.50  2013
# 4    May          -0.10          0.40  2013
# 5    Jun           0.10          0.70  2013
# 6    Jul          -0.10          0.70  2013
# 7    Aug           0.10          0.20  2013
# 8    Sep          -0.10          0.20  2013
# 9    Oct          -0.20          0.10  2013
# 10   Nov          -0.20          0.30  2013
# 11   Dec              0          0.20  2013

# %%
inf13_21.replace({'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7,
                 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}, inplace=True)

# %%
inf13_21
# Out:
#      Month Monthly Change Annual Change  Year
# 0        1          -0.50          1.20  2013
# 1        2           0.80          1.10  2013
# 2        3           0.40          0.50  2013
# 3        4              0          0.50  2013
# 4        5          -0.10          0.40  2013
# ..     ...            ...           ...   ...
# 102      7           0.40          2.20  2021
# 103      8           0.60          2.80  2021
# 104      9           0.50          3.70  2021
# 105     10           0.70          5.10  2021
# 106     11           0.60          5.30  2021
#
# [107 rows x 4 columns]

# %%
inf10_12 = pd.read_csv('economy-factors/inflation-irl-10-12.csv')

# %%
#inf10_12

# %%
date = np.array(inf10_12['Month'])
month_val = []
year = []
for i in range(len(date)):
    split = date[i].split("-")
    month = split[0]
    year1 = "20" + split[-1]
    month_val.append(month)
    year.append(year1)

# %%
inf10_12['Year'] = year
inf10_12['Month'] = month_val

# %%
#inf10_12

# %%
inf10_12.replace({'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7,
                 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}, inplace=True)

# %%
inf10_12
# Out:
#     Month  Monthly Change  Annual Change  Year
# 0       1            -0.6           -3.9  2010
# 1       2             0.4           -3.2  2010
# 2       3             0.1           -3.1  2010
# 3       4             0.2           -2.1  2010
# 4       5             0.6           -1.1  2010
# 5       6             0.1           -0.9  2010
# 6       7             0.0           -0.1  2010
# 7       8             0.7            0.2  2010
# 8       9            -0.1            0.5  2010
# 9      10             0.0            0.7  2010
# 10     11            -0.1            0.6  2010
# 11     12             0.2            1.3  2010
# 12      1            -0.2            1.7  2011
# 13      2             0.9            2.2  2011
# 14      3             0.9            3.0  2011
# 15      4             0.4            3.2  2011
# 16      5             0.1            2.7  2011
# 17      6            -0.1            2.7  2011
# 18      7             0.0            2.7  2011
# ...

# %%
inf10_12.dtypes
# Out:
# Month               int64
# Monthly Change    float64
# Annual Change     float64
# Year               object
# dtype: object

# %%
inf13_21.dtypes
# Out:
# Month              int64
# Monthly Change    object
# Annual Change     object
# Year              object
# dtype: object

# %%
inf13_21["Monthly Change"] = inf13_21["Monthly Change"].astype('float64')
inf13_21["Annual Change"] = inf13_21["Annual Change"].astype('float64')
inf13_21["Year"] = inf13_21["Year"].astype('int64')

# %%
inf13_21.dtypes
# Out:
# Month               int64
# Monthly Change    float64
# Annual Change     float64
# Year                int64
# dtype: object

# %%
inf10_12["Year"] = inf10_12["Year"].astype('int64')

# %%
inf10_12.dtypes
# Out:
# Month               int64
# Monthly Change    float64
# Annual Change     float64
# Year                int64
# dtype: object

# %%
final = inf10_12.append(inf13_21, ignore_index=True)

# %%
final
# Out:
#      Month  Monthly Change  Annual Change  Year
# 0        1            -0.6           -3.9  2010
# 1        2             0.4           -3.2  2010
# 2        3             0.1           -3.1  2010
# 3        4             0.2           -2.1  2010
# 4        5             0.6           -1.1  2010
# ..     ...             ...            ...   ...
# 138      7             0.4            2.2  2021
# 139      8             0.6            2.8  2021
# 140      9             0.5            3.7  2021
# 141     10             0.7            5.1  2021
# 142     11             0.6            5.3  2021
#
# [143 rows x 4 columns]

# %%
#final.to_csv('inflation-irl-month.csv')

# %%
merged_inner1 = pd.merge(left = merged_inner, right = final, left_on=['Year', 'Month'], right_on=['Year', 'Month'])

# %%
merged_inner1.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceLuas  DistanceSecSchool DistanceGPO  \
# ...

# %%
#merged_inner1.drop(columns=['Annual Change'], inplace=True)

# %%
#merged_inner1.to_csv('annual-change-inflation.csv')

# %%
household_income = pd.read_csv('economy-factors/household-income18.csv')

# %%
household_income
# Out:
#                                                Statistic  Year  \
# 0      Compensation of Employees (i.e. Wages and Sala...  2000
# 1      Compensation of Employees (i.e. Wages and Sala...  2000
# 2      Compensation of Employees (i.e. Wages and Sala...  2000
# 3      Compensation of Employees (i.e. Wages and Sala...  2000
# 4      Compensation of Employees (i.e. Wages and Sala...  2000
# ...                                                  ...   ...
# 10540  Index of Disposable Income per Person (excludi...  2018
# 10541  Index of Disposable Income per Person (excludi...  2018
# 10542  Index of Disposable Income per Person (excludi...  2018
# 10543  Index of Disposable Income per Person (excludi...  2018
# 10544  Index of Disposable Income per Person (excludi...  2018
#
#           County and Region          UNIT    VALUE
# 0                     State  Euro Million  42023.0
# 1      Northern and Western  Euro Million   5749.0
# 2                    Border  Euro Million   2542.0
# ...

# %%
household_income1 = household_income.loc[household_income['Statistic'] == 'Total Household Income']

# %%
household_income1 = household_income1.loc[household_income1['Year'] >= 2010]

# %%
household_income1.head()
# Out:
#                    Statistic  Year     County and Region          UNIT  \
# 4588  Total Household Income  2010                 State  Euro Million
# 4589  Total Household Income  2010  Northern and Western  Euro Million
# 4590  Total Household Income  2010                Border  Euro Million
# 4591  Total Household Income  2010               Leitrim  Euro Million
# 4592  Total Household Income  2010                 Sligo  Euro Million
#
#          VALUE
# 4588  116014.0
# 4589   18893.0
# 4590    8413.0
# 4591     735.0
# 4592    1592.0

# %%
number =  np.array(household_income1['VALUE'])
mil = []
for i in range(len(number)):
    million = number[i]
    mil.append(million)

# %%
#mil

# %%
household_income1['Total Household Income (Million €)'] = mil

# %%
household_income1.drop(columns=['UNIT', 'VALUE', 'Statistic'], inplace = True)

# %%
household_income1.head()
# Out:
#       Year     County and Region  Total Household Income (Million €)
# 4588  2010                 State                            116014.0
# 4589  2010  Northern and Western                             18893.0
# 4590  2010                Border                              8413.0
# 4591  2010               Leitrim                               735.0
# 4592  2010                 Sligo                              1592.0

# %%
counties = ['Leitrim', 'Sligo', 'Monaghan', 'Louth', 'Cavan', 'Donegal',
            'Roscommon','Mayo', 'Galway', 'Offaly', 'Laois', 'Dublin',
            'Longford', 'Westmeath', 'Carlow', 'Waterford', 'Kilkenny', 'Wexford', 
            'Tipperary','Wicklow', 'Kildare', 'Meath',
            'Cork', 'Kerry', 'Limerick', 'Clare']

# %%
household_income1.rename(columns = {'County and Region': 'County'}, inplace = True)

# %%
household_income1[household_income1['County'] == 'Cork']
# Out:
#       Year County  Total Household Income (Million €)
# 4611  2010   Cork                             13080.0
# 4648  2011   Cork                             12792.0
# 4685  2012   Cork                             13283.0
# 4722  2013   Cork                             13539.0
# 4759  2014   Cork                             13764.0
# 4796  2015   Cork                             14166.0
# 4833  2016   Cork                             14837.0
# 4870  2017   Cork                             15833.0
# 4907  2018   Cork                             17141.0

# %%
household_income1.head()
# Out:
#       Year                County  Total Household Income (Million €)
# 4588  2010                 State                            116014.0
# 4589  2010  Northern and Western                             18893.0
# 4590  2010                Border                              8413.0
# 4591  2010               Leitrim                               735.0
# 4592  2010                 Sligo                              1592.0

# %%
household_income1 = household_income1.loc[household_income1['County'] == 'Cork']

# %%
#household_income1.to_csv('household-income-cleaned.csv')

# %%
disp = pd.read_csv('economy-factors/dispose-income.csv')

# %%
disp
# Out:
#                                              Statistic Quarter  Ireland UNIT  \
# 0    Household total disposable Income (TDI = B.6G+...  1999Q1  Ireland   €m
# 1    Household total disposable Income (TDI = B.6G+...  1999Q2  Ireland   €m
# 2    Household total disposable Income (TDI = B.6G+...  1999Q3  Ireland   €m
# 3    Household total disposable Income (TDI = B.6G+...  1999Q4  Ireland   €m
# 4    Household total disposable Income (TDI = B.6G+...  2000Q1  Ireland   €m
# ..                                                 ...     ...      ...  ...
# 359                                       Saving Ratio  2020Q3  Ireland    %
# 360                                       Saving Ratio  2020Q4  Ireland    %
# 361                                       Saving Ratio  2021Q1  Ireland    %
# 362                                       Saving Ratio  2021Q2  Ireland    %
# 363                                       Saving Ratio  2021Q3  Ireland    %
#
#        VALUE
# 0    12193.0
# 1    10539.0
# ...

# %%
disp1 = disp.loc[disp['Statistic'].str.contains("Household total disposable Income")]

# %%
quarter = []
yr = []
time = np.array(disp1['Quarter'])
for i in range(len(time)):
    q = time[i][-2:]
    y = time[i][:-2]
    yr.append(y)
    quarter.append(q)

# %%
disp1['Year'] = yr
disp1['Quarter'] = quarter
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/2604286151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp1['Year'] = yr
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/2604286151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp1['Quarter'] = quarter

# %%
disp1.drop(columns=['Statistic', 'UNIT', 'Ireland'], inplace = True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
disp1.rename(columns={'VALUE': 'Household Disposable'}, inplace = True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
disp1
# Out:
#    Quarter  Household Disposable  Year
# 0       Q1               12193.0  1999
# 1       Q2               10539.0  1999
# 2       Q3               11978.0  1999
# 3       Q4               12679.0  1999
# 4       Q1               12487.0  2000
# ..     ...                   ...   ...
# 86      Q3               30669.0  2020
# 87      Q4               31495.0  2020
# 88      Q1               31968.0  2021
# 89      Q2               32321.0  2021
# 90      Q3               32870.0  2021
#
# [91 rows x 3 columns]

# %%
quarters = []
m = np.array(disp1['Quarter'])
for i in range(len(m)):
    if m[i] == "Q1":
        quarters.append(1)
    elif m[i] == "Q2":
        quarters.append(2)
    elif m[i] == "Q3":
        quarters.append(3)
    else:
        quarters.append(4)

# %%
disp1['Quarter'] = quarters
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/1804170279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp1['Quarter'] = quarters

# %%
#disp1.to_csv('disp-income-cleaned.csv')

# %%
irl = merged_inner1.copy()

# %%
irl.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceLuas  DistanceSecSchool DistanceGPO  \
# ...

# %%
quarters = []
one = [1,2,3]
two = [4,5,6]
three = [7,8,9]
four = [10,11,12]
m = np.array(irl['Month'])
for i in range(len(m)):
    if m[i] in one:
        quarters.append(1)
    elif m[i] in two:
        quarters.append(2)
    elif m[i] in three:
        quarters.append(3)
    else:
        quarters.append(4)

# %%
#quarters

# %%
disp1.dtypes
# Out:
# Quarter                   int64
# Household Disposable    float64
# Year                     object
# dtype: object

# %%
disp1['Year'] = disp1['Year'].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/4199198974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disp1['Year'] = disp1['Year'].astype('int64')

# %%
disp1.dtypes
# Out:
# Quarter                   int64
# Household Disposable    float64
# Year                      int64
# dtype: object

# %%
irl.dtypes
# Out:
# Address                       object
# County                        object
# Price (€)                    float64
# VAT Exclusive                  int64
# UsedProperty                   int64
# Property Size Description      int64
# Year                           int64
# Month                          int64
# Town                          object
# Apartment                      int64
# Neighbourhood                 object
# PriceInflation               float64
# Eircode                       object
# Latitude                     float64
# Longitude                    float64
# DistanceIFSC                 float64
# DistanceSchool               float64
# DistancePark                 float64
# DistanceLuas                 float64
# DistanceSecSchool            float64
# DistanceGPO                  float64
# DistanceHospital             float64
# DistanceBeach                float64
# DistanceCar                  float64
# DistanceShops                float64
# ...

# %%
irl['Quarter'] = quarters

# %%
irl.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceSecSchool  DistanceGPO  \
# ...

# %%
merged_inner2 = pd.merge(left = irl, right = disp1, left_on = ['Year', 'Quarter'], right_on = ['Year', 'Quarter'])

# %%
merged_inner2.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceGPO  DistanceHospital DistanceBeach  \
# ...

# %%
#merged_inner2.to_csv('disp-home.csv')

# %%
#merged_inner3['PriceInflation'] = lst

# %%
#merged_inner3.to_csv('inflated-prices.csv')

# %%
deficit = pd.read_csv('economy-factors/state-deficit.csv')

# %%
deficit
# Out:
#                                              Statistic Quarter  State  \
# 0    General Government Surplus/Deficit - ESA2010 C...  2000Q1  State
# 1    General Government Surplus/Deficit - ESA2010 C...  2000Q2  State
# 2    General Government Surplus/Deficit - ESA2010 C...  2000Q3  State
# 3    General Government Surplus/Deficit - ESA2010 C...  2000Q4  State
# 4    General Government Surplus/Deficit - ESA2010 C...  2001Q1  State
# ..                                                 ...     ...    ...
# 169  General Government Surplus/Deficit ESA2010 (as...  2020Q3  State
# 170  General Government Surplus/Deficit ESA2010 (as...  2020Q4  State
# 171  General Government Surplus/Deficit ESA2010 (as...  2021Q1  State
# 172  General Government Surplus/Deficit ESA2010 (as...  2021Q2  State
# 173  General Government Surplus/Deficit ESA2010 (as...  2021Q3  State
#
#              UNIT   VALUE
# 0    Euro Million  1184.0
# 1    Euro Million  2953.0
# 2    Euro Million   767.0
# ...

# %%
deficit = deficit.loc[deficit['Statistic'].str.contains('Code')]

# %%
deficit
# Out:
#                                             Statistic Quarter  State  \
# 0   General Government Surplus/Deficit - ESA2010 C...  2000Q1  State
# 1   General Government Surplus/Deficit - ESA2010 C...  2000Q2  State
# 2   General Government Surplus/Deficit - ESA2010 C...  2000Q3  State
# 3   General Government Surplus/Deficit - ESA2010 C...  2000Q4  State
# 4   General Government Surplus/Deficit - ESA2010 C...  2001Q1  State
# ..                                                ...     ...    ...
# 82  General Government Surplus/Deficit - ESA2010 C...  2020Q3  State
# 83  General Government Surplus/Deficit - ESA2010 C...  2020Q4  State
# 84  General Government Surplus/Deficit - ESA2010 C...  2021Q1  State
# 85  General Government Surplus/Deficit - ESA2010 C...  2021Q2  State
# 86  General Government Surplus/Deficit - ESA2010 C...  2021Q3  State
#
#             UNIT   VALUE
# 0   Euro Million  1184.0
# 1   Euro Million  2953.0
# 2   Euro Million   767.0
# 3   Euro Million   363.0
# ...

# %%
quarter = []
yr = []
time = np.array(deficit['Quarter'])
for i in range(len(time)):
    q = time[i][-1]
    y = time[i][:-2]
    yr.append(y)
    quarter.append(q)

# %%
deficit['Quarter'] = quarter
deficit['Year'] = yr
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/751437742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deficit['Quarter'] = quarter
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/751437742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deficit['Year'] = yr

# %%
deficit
# Out:
#                                             Statistic Quarter  State  \
# 0   General Government Surplus/Deficit - ESA2010 C...       1  State
# 1   General Government Surplus/Deficit - ESA2010 C...       2  State
# 2   General Government Surplus/Deficit - ESA2010 C...       3  State
# 3   General Government Surplus/Deficit - ESA2010 C...       4  State
# 4   General Government Surplus/Deficit - ESA2010 C...       1  State
# ..                                                ...     ...    ...
# 82  General Government Surplus/Deficit - ESA2010 C...       3  State
# 83  General Government Surplus/Deficit - ESA2010 C...       4  State
# 84  General Government Surplus/Deficit - ESA2010 C...       1  State
# 85  General Government Surplus/Deficit - ESA2010 C...       2  State
# 86  General Government Surplus/Deficit - ESA2010 C...       3  State
#
#             UNIT   VALUE  Year
# 0   Euro Million  1184.0  2000
# 1   Euro Million  2953.0  2000
# 2   Euro Million   767.0  2000
# ...

# %%
deficit.drop(columns = ['State', 'UNIT', 'Statistic'], inplace = True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
deficit
# Out:
#    Quarter   VALUE  Year
# 0        1  1184.0  2000
# 1        2  2953.0  2000
# 2        3   767.0  2000
# 3        4   363.0  2000
# 4        1   787.0  2001
# ..     ...     ...   ...
# 82       3 -6533.0  2020
# 83       4 -2097.0  2020
# 84       1 -6226.0  2021
# 85       2 -2114.0  2021
# 86       3 -2898.0  2021
#
# [87 rows x 3 columns]

# %%
deficit['Quarter'] = deficit['Quarter'].astype('int64')
deficit['Year'] = deficit['Year'].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/4147730443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deficit['Quarter'] = deficit['Quarter'].astype('int64')
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/4147730443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deficit['Year'] = deficit['Year'].astype('int64')

# %%
deficit = deficit.loc[deficit['Year'] >= 2010]

# %%
deficit
# Out:
#     Quarter    VALUE  Year
# 40        1 -16526.0  2010
# 41        2  -6318.0  2010
# 42        3 -13611.0  2010
# 43        4 -17309.0  2010
# 44        1  -4462.0  2011
# 45        2  -3971.0  2011
# 46        3 -11424.0  2011
# 47        4  -3568.0  2011
# 48        1  -4747.0  2012
# 49        2  -4042.0  2012
# 50        3  -3446.0  2012
# 51        4  -2671.0  2012
# 52        1  -4071.0  2013
# 53        2  -1905.0  2013
# 54        3  -3041.0  2013
# 55        4  -2493.0  2013
# 56        1  -2784.0  2014
# 57        2  -1429.0  2014
# 58        3  -2070.0  2014
# 59        4   -801.0  2014
# 60        1  -2264.0  2015
# 61        2   -542.0  2015
# 62        3  -1392.0  2015
# 63        4  -1187.0  2015
# 64        1  -1769.0  2016
# 65        2    194.0  2016
# 66        3  -1743.0  2016
# 67        4   1234.0  2016
# 68        1  -1068.0  2017
# 69        2   -101.0  2017
# 70        3  -1889.0  2017
# 71        4   2181.0  2017
# 72        1  -1657.0  2018
# ...

# %%
#merged_inner3.drop(columns=['RPPI', 'Price (€)'], inplace = True)

# %%
merged_inner4 = pd.merge(left = merged_inner2, right = deficit, left_on=['Year', 'Quarter'], right_on=['Year', 'Quarter'])

# %%
merged_inner4.rename(columns = {'VALUE': 'Gov Deficit'}, inplace = True)

# %%
from sklearn import preprocessing
#list for cols to scale
cols_to_scale = ['Unemployment Number','Gov Deficit']

#create and fit scaler
scaler = preprocessing.StandardScaler()
scaler.fit(merged_inner4[cols_to_scale])

#scale selected data
merged_inner4[cols_to_scale] = scaler.transform(merged_inner4[cols_to_scale])

# %%
merged_inner4.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceHospital  DistanceBeach DistanceCar  \
# ...

# %%
#merged_inner4.to_csv('deficit-merged.csv')

# %%
interest = pd.read_csv('economy-factors/retail-interest-rates-monthly.csv')

# %%
interest
# Out:
#                                              Statistic    Month  State UNIT  \
# 0    Variable interest rate and up to one year fixa...  2003M01  State    %
# 1    Variable interest rate and up to one year fixa...  2003M02  State    %
# 2    Variable interest rate and up to one year fixa...  2003M03  State    %
# 3    Variable interest rate and up to one year fixa...  2003M04  State    %
# 4    Variable interest rate and up to one year fixa...  2003M05  State    %
# ..                                                 ...      ...    ...  ...
# 449        Interest rate on consumer loans outstanding  2021M07  State    %
# 450        Interest rate on consumer loans outstanding  2021M08  State    %
# 451        Interest rate on consumer loans outstanding  2021M09  State    %
# 452        Interest rate on consumer loans outstanding  2021M10  State    %
# 453        Interest rate on consumer loans outstanding  2021M11  State    %
#
#      VALUE
# 0     4.08
# 1     4.28
# 2     4.04
# ...

# %%
interest = interest.loc[interest['Statistic'].str.contains('consumer')]

# %%
month = []
year = []
time = np.array(interest['Month'])
for i in range(len(time)):
    yr = time[i][:4]
    mon = time[i][-2:]
    year.append(yr)
    month.append(mon)

# %%
interest['Year'] = year
interest['Year'] = interest['Year'].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/989823793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest['Year'] = year
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/989823793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest['Year'] = interest['Year'].astype('int64')

# %%
interest['Month'] = month
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/3824924701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest['Month'] = month

# %%
interest
# Out:
#                                        Statistic Month  State UNIT  VALUE  \
# 227  Interest rate on consumer loans outstanding    01  State    %   7.38
# 228  Interest rate on consumer loans outstanding    02  State    %   7.36
# 229  Interest rate on consumer loans outstanding    03  State    %   7.24
# 230  Interest rate on consumer loans outstanding    04  State    %   7.04
# 231  Interest rate on consumer loans outstanding    05  State    %   7.18
# ..                                           ...   ...    ...  ...    ...
# 449  Interest rate on consumer loans outstanding    07  State    %   7.23
# 450  Interest rate on consumer loans outstanding    08  State    %   7.27
# 451  Interest rate on consumer loans outstanding    09  State    %   7.29
# 452  Interest rate on consumer loans outstanding    10  State    %   7.31
# 453  Interest rate on consumer loans outstanding    11  State    %   7.37
#
#      Year
# 227  2003
# 228  2003
# 229  2003
# 230  2003
# 231  2003
# ...

# %%
m = np.array(interest['Month'])
fix = []
for i in range(len(m)):
    if m[i][0] == "0":
        stm = m[i][-1]
        fix.append(stm)
    else:
        fix.append(m[i])

# %%
interest['Month'] = fix
interest['Month'] = interest['Month'].astype('int64')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/2386946743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest['Month'] = fix
# C:\Users\user\AppData\Local\Temp/ipykernel_11900/2386946743.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest['Month'] = interest['Month'].astype('int64')

# %%
interest
# Out:
#                                        Statistic  Month  State UNIT  VALUE  \
# 227  Interest rate on consumer loans outstanding      1  State    %   7.38
# 228  Interest rate on consumer loans outstanding      2  State    %   7.36
# 229  Interest rate on consumer loans outstanding      3  State    %   7.24
# 230  Interest rate on consumer loans outstanding      4  State    %   7.04
# 231  Interest rate on consumer loans outstanding      5  State    %   7.18
# ..                                           ...    ...    ...  ...    ...
# 449  Interest rate on consumer loans outstanding      7  State    %   7.23
# 450  Interest rate on consumer loans outstanding      8  State    %   7.27
# 451  Interest rate on consumer loans outstanding      9  State    %   7.29
# 452  Interest rate on consumer loans outstanding     10  State    %   7.31
# 453  Interest rate on consumer loans outstanding     11  State    %   7.37
#
#      Year
# 227  2003
# 228  2003
# 229  2003
# 230  2003
# ...

# %%
interest.drop(columns = ['Statistic', 'UNIT', 'State'], inplace = True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
interest = interest.iloc[:-2]

# %%
interest = interest.loc[interest['Year'] > 2009]

# %%
interest.rename(columns = {'VALUE': 'Interest Consumer'}, inplace = True)

# %%
merged_inner4.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceHospital  DistanceBeach DistanceCar  \
# ...

# %%
merged_inner5 = pd.merge(left = merged_inner4, right = interest, left_on=['Year', 'Month'], right_on=['Year', 'Month'])

# %%
merged_inner5.head()
# Out:
#                                              Address  County  Price (€)  \
# 0                        55 College Square, Terenure  Dublin  447200.00
# 1   Number 7 Belfort House, Sydenham Villas, Dundrum  Dublin  398000.00
# 2  Apartment 16 Cedar Grove, Firhouse Road, Templ...  Dublin  196035.24
# 3                 75 Palmerstown Avenue, Palmerstown  Dublin   95000.00
# 4          17 Churchview Apts, Church Rd, Drumcondra  Dublin  152000.00
#
#    VAT Exclusive  UsedProperty  Property Size Description  Year  Month  \
# 0              0             0                          1  2014      1
# 1              1             1                          0  2014      1
# 2              0             0                          1  2014      1
# 3              1             1                          1  2014      1
# 4              1             1                          2  2014      1
#
#              Town  Apartment  ... DistanceBeach  DistanceCar DistanceShops  \
# ...

# %%
merged_inner5.columns
# Out:
# Index(['Address', 'County', 'Price (€)', 'VAT Exclusive', 'UsedProperty',
#        'Property Size Description', 'Year', 'Month', 'Town', 'Apartment',
#        'Neighbourhood', 'PriceInflation', 'Eircode', 'Latitude', 'Longitude',
#        'DistanceIFSC', 'DistanceSchool', 'DistancePark', 'DistanceLuas',
#        'DistanceSecSchool', 'DistanceGPO', 'DistanceHospital', 'DistanceBeach',
#        'DistanceCar', 'DistanceShops', 'Unemployment Number', 'Monthly Change',
#        'Annual Change', 'Quarter', 'Household Disposable', 'Gov Deficit',
#        'Interest Consumer'],
#       dtype='object')

# %%
merged_inner5.drop(columns = ['Quarter', 'Monthly Change', 'Annual Change'], inplace = True)

# %%
#merged_inner5.to_csv('consumer-interest-dublin.csv')

# %% [markdown]
# ### Analysis of Economic Variables
#
# Let's group prices together instead of treating on them on their own with each data point. This will give us a better understanding of this with the house market in our subset of Dublin data from 2014 to 2021. We are going to check the correlations between montly mean sale price and our selection of economic variables to see if they have any actual significance on the housing market in Cork City.

# %%
res = merged_inner5.groupby(['Year', 'Month'])['Price (€)'].mean().reset_index()

# %%
res.head()
# Out:
#    Year  Month      Price (€)
# 0  2014      1  245514.704706
# 1  2014      2  236284.408235
# 2  2014      3  257295.700769
# 3  2014      4  263131.847500
# 4  2014      5  242528.133333

# %%
res['Price (€)'].plot(figsize = (18, 6), title = 'Average Monthly Sale Price over time for Cork City 2014 - 2021')
# Out:
# <AxesSubplot:title={'center':'Average Monthly Sale Price over time for Cork City 2014 - 2021'}>

# %%
res1 = pd.merge(left = res, right = interest, left_on=['Year', 'Month'], right_on=['Year', 'Month'])

# %%
res1.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer
# 0  2014      1  245514.704706               5.19
# 1  2014      2  236284.408235               5.23
# 2  2014      3  257295.700769               5.26
# 3  2014      4  263131.847500               5.25
# 4  2014      5  242528.133333               5.38

# %%
quarters = []
one = [1,2,3]
two = [4,5,6]
three = [7,8,9]
four = [10,11,12]
m = np.array(res1['Month'])
for i in range(len(m)):
    if m[i] in one:
        quarters.append(1)
    elif m[i] in two:
        quarters.append(2)
    elif m[i] in three:
        quarters.append(3)
    else:
        quarters.append(4)

# %%
res1['Quarter'] = quarters

# %%
res1.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer  Quarter
# 0  2014      1  245514.704706               5.19        1
# 1  2014      2  236284.408235               5.23        1
# 2  2014      3  257295.700769               5.26        1
# 3  2014      4  263131.847500               5.25        2
# 4  2014      5  242528.133333               5.38        2

# %%
res2 = pd.merge(left = res1, right = disp1, left_on = ['Year', 'Quarter'], right_on = ['Year', 'Quarter'])

# %%
res2.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer  Quarter  \
# 0  2014      1  245514.704706               5.19        1
# 1  2014      2  236284.408235               5.23        1
# 2  2014      3  257295.700769               5.26        1
# 3  2014      4  263131.847500               5.25        2
# 4  2014      5  242528.133333               5.38        2
#
#    Household Disposable
# 0               22610.0
# 1               22610.0
# 2               22610.0
# 3               22790.0
# 4               22790.0

# %%
res3 = pd.merge(left = res2, right = unemploy_all, left_on=['Year', 'Month'], right_on=['Year', 'Month'])

# %%
res3.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer  Quarter  \
# 0  2014      1  245514.704706               5.19        1
# 1  2014      2  236284.408235               5.23        1
# 2  2014      3  257295.700769               5.26        1
# 3  2014      4  263131.847500               5.25        2
# 4  2014      5  242528.133333               5.38        2
#
#    Household Disposable  Unemployment Number
# 0               22610.0               399244
# 1               22610.0               397722
# 2               22610.0               390916
# 3               22790.0               388258
# 4               22790.0               388486

# %%
res4 = pd.merge(left = res3, right = deficit, left_on=['Year', 'Quarter'], right_on=['Year', 'Quarter'])

# %%
res4.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer  Quarter  \
# 0  2014      1  245514.704706               5.19        1
# 1  2014      2  236284.408235               5.23        1
# 2  2014      3  257295.700769               5.26        1
# 3  2014      4  263131.847500               5.25        2
# 4  2014      5  242528.133333               5.38        2
#
#    Household Disposable  Unemployment Number   VALUE
# 0               22610.0               399244 -2784.0
# 1               22610.0               397722 -2784.0
# 2               22610.0               390916 -2784.0
# 3               22790.0               388258 -1429.0
# 4               22790.0               388486 -1429.0

# %%
res4.rename(columns = {'VALUE': 'Deficit'}, inplace = True)

# %%
res4.head()
# Out:
#    Year  Month      Price (€)  Interest Consumer  Quarter  \
# 0  2014      1  245514.704706               5.19        1
# 1  2014      2  236284.408235               5.23        1
# 2  2014      3  257295.700769               5.26        1
# 3  2014      4  263131.847500               5.25        2
# 4  2014      5  242528.133333               5.38        2
#
#    Household Disposable  Unemployment Number  Deficit
# 0               22610.0               399244  -2784.0
# 1               22610.0               397722  -2784.0
# 2               22610.0               390916  -2784.0
# 3               22790.0               388258  -1429.0
# 4               22790.0               388486  -1429.0

# %%
corr = res4.corr()

plt.figure(figsize = (30,10))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
 # let's visualize the correlations better using a barchart
cols = res4.dtypes[res4.dtypes != 'object'].index
corrs=[]
for item in cols:
    corrs.append((res4[item].corr(res4['Price (€)'])))
    
ist = pd.DataFrame({'cols': cols, 'corrs': corrs})
ist = ist.sort_values(by = 'corrs', ascending = False)
plt.subplots(figsize = (19, 4))
sns.barplot(x = ist['cols'], y = ist['corrs'])
plt.xticks(rotation = 45)
plt.ylabel('Correlation', fontsize = 13)
plt.xlabel('Column-Names', fontsize = 13)
plt.title('Features mostly correlated to mean sale price (€) in Dublin')
plt.show()

# %% [markdown]
# ## Lets' check our Pearson, Kendall and Spearman Correlations
#
# These will provide us with p-values to check statistical significance.

# %%
from scipy.stats import kendalltau, pearsonr, spearmanr

def kendall_pval(x,y):
    return kendalltau(x,y)[1]
    
def pearsonr_pval(x,y):
    return pearsonr(x,y)[1]
    
def spearmanr_pval(x,y):
    return spearmanr(x,y)[1]

# %%
corr = res4.corr(method = pearsonr_pval)

plt.figure(figsize = (30,10))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
corr = res4.corr(method = kendall_pval)

plt.figure(figsize = (30,10))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
corr = res4.corr(method = spearmanr_pval)

plt.figure(figsize = (30,10))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
rho = res4.corr()
pval = res4.corr(method = lambda x, y: pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01, 0.05, 0.1] if x <= t]))
#p = p['Price (€)']
rho.round(2).astype(str) + p

## asterisk is statistically significant
# Out:
#                           Year    Month Price (€) Interest Consumer  Quarter  \
# Year                    1.0***    -0.07   0.67***           0.64***    -0.07
# Month                    -0.07   1.0***     -0.02              0.07  0.97***
# Price (€)              0.67***    -0.02    1.0***           0.51***      0.0
# Interest Consumer      0.64***     0.07   0.51***            1.0***     0.07
# Quarter                  -0.07  0.97***       0.0              0.07   1.0***
# Household Disposable   0.98***     0.05   0.63***           0.59***     0.05
# Unemployment Number   -0.94***    -0.08  -0.63***          -0.79***    -0.08
# Deficit               -0.28***  0.43***   -0.22**            0.24**  0.44***
#
#                      Household Disposable Unemployment Number   Deficit
# Year                              0.98***            -0.94***  -0.28***
# Month                                0.05               -0.08   0.43***
# ...
